# %%
import pandas as pd
import numpy as np

# %%
# Reading in small sample to get an idea of the data
df=pd.read_csv('train_v2.csv',nrows=10)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Columns: 771 entries, id to loss
# dtypes: float64(484), int64(274), object(12), uint64(1)
# memory usage: 60.3+ KB

# %% [markdown]
# There are 771 columns out of which 1 is the loss value which is to be predicted. There are 12 features which are strings, hence would need to be converted to numbers. For data cleaning and preparation, I would need to do 3 things:
# 1) Drop unnecessary columns
# 2) Convert categorical variables to discrete numerical variables
# 3) Fill in missing values
# 4) Use PCA to reduce dimensionality of feature space

# %%
# Looking at the features with object dtype
g=df.columns.to_series().groupby(df.dtypes).groups
df.loc[:,g[list(g.keys())[-1]]]
# Out:
#                       f138                    f277  \
# 0    754485076006959972352   683091368180479950848
# 1        15300000000000000     2140000000000000000
# 2      6910365323840000000       69200000000000000
# 3  11225194901267999096832      295000000000000000
# 4          108000000000000       23100000000000000
# 5       289000000000000000    11995784877002000384
# 6      5930000000000000000        1180000000000000
# 7  18874963171119999221760  3620246973781699985408
# 8       756000000000000000        1600000000000000
# 9        47800000000000000   738631136553930063872
#
#                              f390                                      f391  \
# 0   10370164393071999997033054208    13621142007705000132589703585884798976
# 1    5098137566366599989877014528     5366154527659000357778647583412977664
# 2   26400269714792999161039945728    36117033568522998807722429270944907264
# 3    9333818143939599917454983168    12638526060843999893906772076814925824
# ...

# %% [markdown]
# These look like numbers, although they are very large. So not sure what to do with them

# %%
# Converting these features to floats
df[g[list(g.keys())[-1]]]=df[g[list(g.keys())[-1]]].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Columns: 771 entries, id to loss
# dtypes: float64(496), int64(274), uint64(1)
# memory usage: 60.3 KB
